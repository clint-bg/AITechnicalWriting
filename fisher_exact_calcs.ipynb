# %%
from scipy.stats import fisher_exact,ttest_ind, chi2_contingency
import pandas as pd

# %%
fisher_exact([[47,25],[27,20]],alternative='greater')
# Out:
# SignificanceResult(statistic=1.3925925925925926, pvalue=0.2516613550746573)
